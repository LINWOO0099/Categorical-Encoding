# %% [markdown]
# <a href="https://colab.research.google.com/github/LINWOO0099/Categorical-Encoding/blob/api/API_key_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. Check Current Directory

# %%
# !pwd
# Out:
# /content/ai_ml_course

# %% [markdown]
# ### 2. Create Project Folder

# %%
# !mkdir ai_ml_course

# %% [markdown]
# ### 3. Navigate Into Project Folder

# %%
# %cd ai_ml_course
# Out:
# /content/ai_ml_course/ai_ml_course

# %% [markdown]
# ### 4. Create Subfolders

# %%
# !mkdir data notebooks scripts docs

# %% [markdown]
# ### 5. Verify Folder Structure

# %%
# !ls
# Out:
# data  docs  notebooks  scripts

# %% [markdown]
# ### 6. Check Python Version

# %%
# !python3 --version
# Out:
# Python 3.12.13

# %% [markdown]
# ### 7. Create Python Script (using `touch`)

# %%
# !touch scripts/masai_init.py

# %% [markdown]
# ### 8. Create Environment File (using `touch`)

# %%
# !touch .env.example

# %% [markdown]
# ### 9. Save Script Directly from Jupyter

# %%
script = """
import math
import datetime

print("AI/ML Environment Initialized")

number = 25

print("Square Root:", math.sqrt(number))
print("Power:", math.pow(number, 2))

print("Current Time:", datetime.datetime.now())
"""

with open("scripts/masai_init.py", "w") as file:
    file.write(script)

print("Script saved successfully!")
# Out:
# Script saved successfully!

# %% [markdown]
# ### 10. Run the Python Script in Jupyter

# %%
# !python scripts/masai_init.py
# Out:
# AI/ML Environment Initialized
# Square Root: 5.0
# Power: 625.0
# Current Time: 2026-05-26 19:19:58.088974

# %% [markdown]
# ### 11. Install Packages in Jupyter

# %%
# !pip install numpy pandas matplotlib scikit-learn

# %% [markdown]
# ### 12. Secure API Key Example: Create `.env.example`

# %%
env_text = """
OPENAI_API_KEY=your_api_key_here
"""

with open(".env.example", "w") as file:
    file.write(env_text)

print(".env.example created")
# Out:
# .env.example created

# %% [markdown]
# ### 13. Final Folder Structure Check

# %%
# !find .
# Out:
# .
# ./data
# ./docs
# ./.env.example
# ./scripts
# ./scripts/masai_init.py
# ./notebooks
